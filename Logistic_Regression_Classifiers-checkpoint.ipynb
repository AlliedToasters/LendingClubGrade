# %% [markdown]
# <H1>Challenge: Build Three Logistic Regression Classifiers</H1><br><br>
# I'm revisiting this loan data to complete this excercise. I'm going to build three logistic regressions: a "vanilla" logreg, a ridge, and lasso.
#
# I tinker excessively with parameters to find the best performers by a number of different metrics. Then, I train my models on this set and test them on future loans (from 2012-13).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from math import e
from sklearn.preprocessing import scale
from sklearn.linear_model import LogisticRegression
from cleaning_funcs import treat_loan_data
# %matplotlib inline

sns.set_style('whitegrid')

df = pd.read_csv(
    'LoanStats3a_securev1.csv',
    skipinitialspace=True,
    header=1
)

df = df[:-2] #Drop last two "summary" rows
df = df[:39786:] #Drop another summary row
# Out:
# /home/alliedtoasters/anaconda3/envs/dspy3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (0,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
can_use = [] #These are the features that lenders can see for loans on the market.

can_use += [     
    'issue_d',
    'loan_amnt',            
    'sub_grade',            
    'int_rate',
    'fico_range_low',
    'term',
    'installment',
    'home_ownership',
    'emp_title', 
    'emp_length',
    'zip_code', 
    'addr_state', 
    'verification_status', 
    'application_type', 
    'annual_inc',
    'annual_inc_joint',
    'dti',
    'dti_joint',
    'earliest_cr_line',
    'open_acc',
    'total_acc',
    'revol_bal',
    'revol_util',
    'inq_last_6mths',
    'acc_now_delinq',
    'delinq_amnt',
    'delinq_2yrs',
    'mths_since_last_delinq',
    'pub_rec',
    'mths_since_last_record',
    'collections_12_mths_ex_med'    
]

loans = df[can_use + ['loan_status']].copy()    #Drop the columns we don't need.

# %% [markdown]
# <H2>Data Preparation</H2>
#
# Let the cleaning begin.
#
# <H3>Input Variables</H3><br>
# I'll start by converting the input variables to numeric/usable types. I wrote the cleaning script called <a href='https://github.com/AlliedToasters/LendingClubGrade/blob/master/cleaning_funcs.py'>cleaning_funcs.py</a> to accomplish this.

# %%
loans = treat_loan_data(loans, 2011) #See cleaning_funcs.py for details
# Out:
# /home/alliedtoasters/thinkful/loans/cleaning_funcs.py:214: RuntimeWarning: divide by zero encountered in log
#   loans['log_used_cred'] = np.where(loans.used_cred_bal < 1, 0, np.log(loans.used_cred_bal)) #log of used cred bal

# %% [markdown]
# <H3>Binary Outcome: "Good" or "Bad" Loans</H3>
#
# <br>I'll break the "loan status" variable into two groups: "good," which are the loans that pay on time or early, and "bad," which are late by any amount of time (from one day late to default/charged off).

# %%
good_statuses = ['Current', 'Fully Paid']
loans['is_good'] = np.where((loans.loan_status.isin(good_statuses)), 1, 0)

# %% [markdown]
# <H2>Grabbing Data and Holdout Group</H2><br>
# To evaluate model performance, I'll shuffle the rows in the data frame and reserve half for training, the second half for testing.

# %%
fts = [                     #Pick my favorite features.
    'issue_d',
    'loan_amnt',            
    'sub_grade',
    'fico_range_low',
    'term_type',
    'installment',
    'home_ownership',
    'emp_length',
    'verification_status', 
    'application_type',
    'log_inc_joint',
    'dti_joint',
    'fcl_before_loan',
    'open_acc',
    'total_acc',
    'log_used_cred',
    'inq_last_6mths',
    'acc_now_delinq',
    'delinq_2yrs',
    'mths_since_last_delinq',
    'mths_since_last_record',
    'log_cf'
]

loans = loans.sample(frac=1)   #shuffle rows
cutoff = int(len(loans)/2)

train = loans[:cutoff]

X_train = train[fts]
Y_train = train['is_good']

X_test = loans[fts][cutoff:]
Y_test = loans['is_good'][cutoff:]

# %%
X_train = scale(X_train)
X_test = scale(X_test)

# %% [markdown]
# <H2>Logistic Regression Models<H2>
# <H3>Model 1: "Vanilla" Logistic Regression</H3><br>
# This data suffers from a class weight imbalance. Almost 86% of the loans are in the "good loan" class. We can modify performance by varying the "false" outcome weight parameter of our classic logistic regression model.

# %%
#Test 'vanilla' model over a range of class weight parameters
param = []
tn = []
fn = []
fp = []
tp = []
acc = []

for val in range(1, 160):
    prm = val/4
    param.append(prm)
    vlr = LogisticRegression(C=1e7, class_weight={0:prm, 1:1})
    vlr_fit = vlr.fit(X_train, Y_train)
    Y_ = vlr_fit.predict(X_test)
    
    tab = pd.crosstab(Y_, Y_test)
    if len(tab) == 1:
        fp.append(tab.iloc[0,0])
        tp.append(tab.iloc[0,1])
        fn.append(0)
        tn.append(0)
        acc.append(len(Y_test[Y_test==1])/(len(Y_test)))
    else:
        tn.append(tab.iloc[0,0])
        fn.append(tab.iloc[0,1])
        fp.append(tab.iloc[1,0])
        tp.append(tab.iloc[1,1])
        acc.append((tab.iloc[0,0]+tab.iloc[1,1])/tab.sum().sum())

result1 = pd.DataFrame()
result1['weight'] = param
result1['tn'] = tn
result1['fn'] = fn
result1['fp'] = fp
result1['tp'] = tp
result1['accuracy'] = acc
result1['negatives_identified'] = result1.tn/(result1.tn+result1.fp)
result1['positives_identified'] = result1.tp/(result1.tp+result1.fn)
result1['success rate of recommended loans'] = result1.tp/(result1.tp + result1.fp)
result1['loans recommended'] = (result1.tp+result1.fp) / len(X_test)

# %%
#Visualize results. 
fig = plt.figure(figsize=(10, 7))
for ft in ['accuracy', 'success rate of recommended loans', 'loans recommended']:
    plt.plot(result1.weight, result1[ft], label=ft);

plt.legend(loc=5);
plt.xlabel('Class Weight Parameter');
plt.ylabel('Proportion');
plt.title('Model Performance over "False" Class Weight Parameter');

# %% [markdown]
# <H3>Results Interpretation</H3><br>
# The maximum accuracy of this model occurs when the model predicts all positive results (low negative class weight). In practice, lenders would want to use this model to avoid "bad" loans. By increasing the "False" class weight parameter, we can improve the performance of recommended loans, at the cost of reducing the overall number of loans recommended and the overall accuracy of the model (with increasing false negatives).

# %%
#The most accurate results are those that recommend almost all of the loans.
result1.loc[result1.accuracy.sort_values(ascending=False).index].head()
# Out:
#    weight  tn  fn    fp     tp  accuracy  negatives_identified  \
# 2    0.75   3   0  2852  17038  0.856633              0.001051
# 0    0.25   0   0  2855  17038  0.856482              0.000000
# 1    0.50   0   0  2855  17038  0.856482              0.000000
# 3    1.00  12  16  2843  17022  0.856281              0.004203
# 4    1.25  28  62  2827  16976  0.854773              0.009807
#
#    positives_identified  success rate of recommended loans  loans recommended
# 2              1.000000                           0.856611           0.999849
# 0              1.000000                           0.856482           1.000000
# 1              1.000000                           0.856482           1.000000
# 3              0.999061                           0.856884           0.998592
# 4              0.996361                           0.857244           0.995476

# %%
#The very best of the 100% successful results offer only about 200 loans out of 17,000, less than 1%
result1.loc[result1.loc[result1['success rate of recommended loans']==1].tp.sort_values(ascending=False).index].head()
# Out:
#      weight    tn     fn  fp   tp  accuracy  negatives_identified  \
# 118   29.75  2855  16842   0  196  0.153371                   1.0
# 119   30.00  2855  16855   0  183  0.152717                   1.0
# 120   30.25  2855  16862   0  176  0.152365                   1.0
# 121   30.50  2855  16872   0  166  0.151862                   1.0
# 122   30.75  2855  16879   0  159  0.151511                   1.0
#
#      positives_identified  success rate of recommended loans  \
# 118              0.011504                                1.0
# 119              0.010741                                1.0
# 120              0.010330                                1.0
# 121              0.009743                                1.0
# 122              0.009332                                1.0
#
#      loans recommended
# 118           0.009853
# 119           0.009199
# 120           0.008847
# 121           0.008345
# 122           0.007993

# %% [markdown]
# To address this tradeoff, I would ask the lender to choose a lowest acceptable success rate (for example, a 97% success rate may be acceptable.) That gives us a reasonable number of loans to choose from:

# %%
#With the 97% success rate threshold, we get to choose from about 2,000 loans or about 10% of all loans.
result1.loc[result1.loc[result1['success rate of recommended loans']>.97].tp.sort_values(ascending=False).index].head()
# Out:
#     weight    tn     fn  fp    tp  accuracy  negatives_identified  \
# 69   17.50  2797  15096  58  1942  0.238225              0.979685
# 70   17.75  2801  15174  54  1864  0.234505              0.981086
# 71   18.00  2803  15255  52  1783  0.230533              0.981786
# 72   18.25  2806  15331  49  1707  0.226864              0.982837
# 73   18.50  2808  15421  47  1617  0.222440              0.983538
#
#     positives_identified  success rate of recommended loans  loans recommended
# 69              0.113981                           0.971000           0.100538
# 70              0.109403                           0.971846           0.096416
# 71              0.104648                           0.971662           0.092244
# 72              0.100188                           0.972096           0.088272
# 73              0.094906                           0.971755           0.083648

# %% [markdown]
# <H3>Model 2: Ridge Logistic Regression</H3><br>
# The ridge regression model offers us another parameter to modify. In the sklearn module, the coefficient limitation penalty is the inverse of the C parameter. We can vary both the class weight and the C coefficient to see if the ridge regression offers any improvement in performance over the "vanilla" model.

# %%
#Vary both C and class weight parameters and record results.
C_param = []
weight_ = []
tn = []
fn = []
fp = []
tp = []
acc = []

for wt in range(3, 90):
    wgt = wt/3
    for val in range(1, 100):
        r_ = -val/10
        prm = e**(r_)
        C_param.append(prm)
        weight_.append(wgt)
        vlr = LogisticRegression(penalty='l2', C=prm, class_weight={0:wgt, 1:1})
        vlr_fit = vlr.fit(X_train, Y_train)
        Y_ = vlr_fit.predict(X_test)

        tab = pd.crosstab(Y_, Y_test)
        if len(tab) == 1:
            fp.append(tab.iloc[0,0])
            tp.append(tab.iloc[0,1])
            fn.append(0)
            tn.append(0)
            acc.append(len(Y_test[Y_test==1])/(len(Y_test)))
        else:
            tn.append(tab.iloc[0,0])
            fn.append(tab.iloc[0,1])
            fp.append(tab.iloc[1,0])
            tp.append(tab.iloc[1,1])
            acc.append((tab.iloc[0,0]+tab.iloc[1,1])/tab.sum().sum())

result2 = pd.DataFrame()
result2['log_C'] = np.log(C_param)
result2['class_weight'] = weight_
result2['tn'] = tn
result2['fn'] = fn
result2['fp'] = fp
result2['tp'] = tp
result2['accuracy'] = acc
result2['negatives_identified'] = result2.tn/(result2.tn+result2.fp)
result2['positives_identified'] = result2.tp/(result2.tp+result2.fn)
result2['pred_rate'] = result2.tp/(result2.tp + result2.fp)
result2['num_pred'] = (result2.tp+result2.fp) / len(X_test)

# %%
#Visualize recommended loan performance over both parameters with heatmap
image=pd.DataFrame(columns=result2.class_weight.unique(), index=result2.log_C.unique())
for row in result2.index:
    wg = result2.loc[row].class_weight
    C_prm = result2.loc[row].log_C
    image.set_value(C_prm, wg, result2.loc[row].pred_rate)
image = image[image.columns].astype(float)

cols = image.columns
nw_cols = []
rows = image.index
nw_rows = []
for col in cols:
    nw_cols.append(str(col)[:5])
for row in rows:
    nw_rows.append(str(row)[:5])
image.columns = nw_cols
image.index = nw_rows

fig, ax = plt.subplots(figsize=(7, 5));
sns.heatmap(image);
plt.xlabel('Weight');
plt.ylabel('Log of C parameter');
plt.title('L2 Ridge Regression Results\nProportion of Predicted "Good" Loans Repaid in Full');

# %%
#Visualize accuracy
image=pd.DataFrame(columns=result2.class_weight.unique(), index=result2.log_C.unique())
for row in result2.index:
    wg = result2.loc[row].class_weight
    C_prm = result2.loc[row].log_C
    image.set_value(C_prm, wg, result2.loc[row].accuracy)
    
image = image[image.columns].astype(float)

cols = image.columns
nw_cols = []
rows = image.index
nw_rows = []
for col in cols:
    nw_cols.append(str(col)[:5])
for row in rows:
    nw_rows.append(str(row)[:5])
image.columns = nw_cols
image.index = nw_rows

fig, ax = plt.subplots(figsize=(7, 5));
sns.heatmap(image);
plt.xlabel('Class Weight ("False" outcome)');
plt.ylabel('Log of C parameter');
plt.title('L2 "Ridge" Regression Results\nPrediction Accuracy');

# %% [markdown]
# <H3>Results Interpretation</H3><br>
# With the ridge regression, we never actually get a 100% recommended loan performance. The maximum performance is around 99%, but this threshold is still pretty limited. We'll compare at the 97% threshold with the vanilla model as well, and see if we can improve maximum accuracy as well.

# %%
#At 100% performance, we get about 240 loans to choose from, or about 1.2% of all loans.
result2.loc[result2.pred_rate.sort_values(ascending=False).index].head()
# Out:
#       log_C  class_weight    tn     fn  fp   tp  accuracy  \
# 8479   -6.5     29.333333  2855  16796   0  242  0.155683
# 8518   -0.5     29.666667  2855  16840   0  198  0.153471
# 8515   -0.2     29.666667  2855  16840   0  198  0.153471
# 8514   -0.1     29.666667  2855  16840   0  198  0.153471
# 8364   -4.9     29.000000  2855  16806   0  232  0.155180
#
#       negatives_identified  positives_identified  pred_rate  num_pred
# 8479                   1.0              0.014204        1.0  0.012165
# 8518                   1.0              0.011621        1.0  0.009953
# 8515                   1.0              0.011621        1.0  0.009953
# 8514                   1.0              0.011621        1.0  0.009953
# 8364                   1.0              0.013617        1.0  0.011662

# %%
#At 97% performance threshold, we get about 2,060 loans or 10.4% of total loans. slight improvement over vanilla model.
result2.loc[result2.loc[result2.pred_rate>.97].tp.sort_values(ascending=False).index].head()
# Out:
#       log_C  class_weight    tn     fn  fp    tp  accuracy  \
# 4902   -5.2     17.333333  2794  15038  61  2000  0.240989
# 4881   -3.1     17.333333  2794  15038  61  2000  0.240989
# 4903   -5.3     17.333333  2794  15039  61  1999  0.240939
# 4880   -3.0     17.333333  2794  15039  61  1999  0.240939
# 4901   -5.1     17.333333  2794  15040  61  1998  0.240889
#
#       negatives_identified  positives_identified  pred_rate  num_pred
# 4902              0.978634              0.117385   0.970403  0.103604
# 4881              0.978634              0.117385   0.970403  0.103604
# 4903              0.978634              0.117326   0.970388  0.103554
# 4880              0.978634              0.117326   0.970388  0.103554
# 4901              0.978634              0.117267   0.970374  0.103504

# %%
#Very slight improvement on max accuracy.
result2.loc[result2.accuracy.sort_values(ascending=False).index].head()
# Out:
#     log_C  class_weight  tn  fn    fp     tp  accuracy  negatives_identified  \
# 58   -5.9           1.0   6   0  2849  17038  0.856784              0.002102
# 59   -6.0           1.0   6   0  2849  17038  0.856784              0.002102
# 61   -6.2           1.0   5   0  2850  17038  0.856734              0.001751
# 60   -6.1           1.0   5   0  2850  17038  0.856734              0.001751
# 49   -5.0           1.0  11   6  2844  17032  0.856734              0.003853
#
#     positives_identified  pred_rate  num_pred
# 58              1.000000   0.856741  0.999698
# 59              1.000000   0.856741  0.999698
# 61              1.000000   0.856698  0.999749
# 60              1.000000   0.856698  0.999749
# 49              0.999648   0.856913  0.999145

# %% [markdown]
# We see some modest improvements over the vanilla model by varying the coefficient size penalty. At the 97% performance threshold, we get over 10% of the loans to choose from. Best accuracy improved negligibly.

# %% [markdown]
# <H3>Model 3: Lasso Logistic Regression</H3><br>
# As with ridge regression, the lasso l1 penalty has a weight parameter that scales inversely with the sklearn C value. Let's vary the same parameters in the same way as before, only changing the penalty function to the p=1 "l1" norm.

# %%
C_param = []
weight_ = []
tn = []
fn = []
fp = []
tp = []
acc = []

for wt in range(3, 90):
    wgt = wt/3
    for val in range(1, 100):
        r_ = -val/10
        prm = e**(r_)
        C_param.append(prm)
        weight_.append(wgt)
        vlr = LogisticRegression(penalty='l1', C=prm, class_weight={0:wgt, 1:1})
        vlr_fit = vlr.fit(X_train, Y_train)
        Y_ = vlr_fit.predict(X_test)

        tab = pd.crosstab(Y_, Y_test)
        if len(tab) == 1:
            fp.append(tab.iloc[0,0])
            tp.append(tab.iloc[0,1])
            fn.append(0)
            tn.append(0)
            acc.append(len(Y_test[Y_test==1])/(len(Y_test)))
        else:
            tn.append(tab.iloc[0,0])
            fn.append(tab.iloc[0,1])
            fp.append(tab.iloc[1,0])
            tp.append(tab.iloc[1,1])
            acc.append((tab.iloc[0,0]+tab.iloc[1,1])/tab.sum().sum())

result3 = pd.DataFrame()
result3['log_C'] = np.log(C_param)
result3['class_weight'] = weight_
result3['tn'] = tn
result3['fn'] = fn
result3['fp'] = fp
result3['tp'] = tp
result3['accuracy'] = acc
result3['negatives_identified'] = result3.tn/(result3.tn+result3.fp)
result3['positives_identified'] = result3.tp/(result3.tp+result3.fn)
result3['pred_rate'] = result3.tp/(result3.tp + result3.fp)
result3['num_pred'] = (result3.tp+result3.fp) / len(X_test)

# %%
image=pd.DataFrame(columns=result3.class_weight.unique(), index=result3.log_C.unique())
for row in result3.index:
    wg = result3.loc[row].class_weight
    C_prm = result3.loc[row].log_C
    image.set_value(C_prm, wg, result3.loc[row].pred_rate)
    
image = image[image.columns].astype(float)

cols = image.columns
nw_cols = []
rows = image.index
nw_rows = []
for col in cols:
    nw_cols.append(str(col)[:5])
for row in rows:
    nw_rows.append(str(row)[:5])
image.columns = nw_cols
image.index = nw_rows

fig, ax = plt.subplots(figsize=(7, 5));
sns.heatmap(image);
plt.xlabel('Weight');
plt.ylabel('Log of C parameter');
plt.title('L1 "lasso" Regression Results\nProportion of Predicted "Good" Loans Repaid in Full');

# %%
image=pd.DataFrame(columns=result3.class_weight.unique(), index=result3.log_C.unique())
for row in result3.index:
    wg = result3.loc[row].class_weight
    C_prm = result3.loc[row].log_C
    image.set_value(C_prm, wg, result3.loc[row].accuracy)
    
image = image[image.columns].astype(float)

cols = image.columns
nw_cols = []
rows = image.index
nw_rows = []
for col in cols:
    nw_cols.append(str(col)[:5])
for row in rows:
    nw_rows.append(str(row)[:5])
image.columns = nw_cols
image.index = nw_rows

fig, ax = plt.subplots(figsize=(7, 5));
sns.heatmap(image);
plt.xlabel('Weight');
plt.ylabel('Log of C parameter');
plt.title('L1 "lasso" Regression Results\nPrediction accuracy');

# %% [markdown]
# <H3>Results Interpretation</H3><br>
# There is a clear boundary on the visualizations. This is where the lasso algorithm collapses some coefficients to zero. Let's see how it compares to the previous models.

# %%
#100% performance yields slightly more recommendations, 1.4% of all loans.
result3.loc[result3[result3.pred_rate==1].tp.sort_values(ascending=False).index].head()
# Out:
#       log_C  class_weight    tn     fn  fp   tp  accuracy  \
# 7962   -4.3     27.666667  2855  16762   0  276  0.157392
# 8057   -3.9     28.000000  2855  16778   0  260  0.156588
# 8058   -4.0     28.000000  2855  16780   0  258  0.156487
# 8061   -4.3     28.000000  2855  16781   0  257  0.156437
# 8059   -4.1     28.000000  2855  16782   0  256  0.156387
#
#       negatives_identified  positives_identified  pred_rate  num_pred
# 7962                   1.0              0.016199        1.0  0.013874
# 8057                   1.0              0.015260        1.0  0.013070
# 8058                   1.0              0.015143        1.0  0.012969
# 8061                   1.0              0.015084        1.0  0.012919
# 8059                   1.0              0.015025        1.0  0.012869

# %%
#97% performance threshold offers ~2,100 recommendations, or 10.5% of all loans.
result3.loc[result3[result3.pred_rate>.97].num_pred.sort_values(ascending=False).index].head()
# Out:
#       log_C  class_weight    tn     fn  fp    tp  accuracy  \
# 4790   -3.9     17.000000  2794  15008  61  2030  0.242497
# 4791   -4.0     17.000000  2794  15019  61  2019  0.241944
# 4852   -0.2     17.333333  2794  15045  61  1993  0.240637
# 4851   -0.1     17.333333  2794  15045  61  1993  0.240637
# 4854   -0.4     17.333333  2794  15046  61  1992  0.240587
#
#       negatives_identified  positives_identified  pred_rate  num_pred
# 4790              0.978634              0.119145   0.970827  0.105112
# 4791              0.978634              0.118500   0.970673  0.104559
# 4852              0.978634              0.116974   0.970302  0.103252
# 4851              0.978634              0.116974   0.970302  0.103252
# 4854              0.978634              0.116915   0.970287  0.103202

# %%
#Overall best accuracy is worse than ridge model.
result3.loc[result3.accuracy.sort_values(ascending=False).index].head()
# Out:
#      log_C  class_weight  tn  fn    fp     tp  accuracy  negatives_identified  \
# 153   -5.5      1.333333   7   3  2848  17035  0.856683              0.002452
# 35    -3.6      1.000000   8   5  2847  17033  0.856633              0.002802
# 156   -5.8      1.333333   3   0  2852  17038  0.856633              0.001051
# 155   -5.7      1.333333   3   1  2852  17037  0.856583              0.001051
# 260   -6.3      1.666667   4   2  2851  17036  0.856583              0.001401
#
#      positives_identified  pred_rate  num_pred
# 153              0.999824   0.856762  0.999497
# 35               0.999707   0.856791  0.999347
# 156              1.000000   0.856611  0.999849
# 155              0.999941   0.856604  0.999799
# 260              0.999883   0.856640  0.999698

# %% [markdown]
# The lasso model has performed best on all fronts, though maximum accuracy was improved only slightly.<br>
# By these metrics, the lasso model performs the best all around.<br>
# <H2>Try It</H2><br>
# I'd like to test this model on a different data set. I'll use the optimum parameters and train with all of the data. I make three models: the 100% performance model, the 97% performance model, and the maximum accuracy model.

# %%
X = loans[fts]
Y = loans['is_good']

max_perf = LogisticRegression(penalty='l1', C=e**(-4.3), class_weight={0:27.666667, 1:1})
max_perf = max_perf.fit(X, Y)

perf_97 = LogisticRegression(penalty='l1', C=e**(-3.9), class_weight={0:17, 1:1})
perf_97 = perf_97.fit(X, Y) #Best performer at 97% threshold

mdm_mod = LogisticRegression(penalty='l2', C=e**(-7.0), class_weight={0:4.666667, 1:1})
mdm_mod = mdm_mod.fit(X, Y) #Best performer at 90% threshold, more moderate parameters 

max_acc = LogisticRegression(penalty='l2', C=e**(-5.9), class_weight={0:1, 1:1})
max_acc = max_acc.fit(X, Y)  #Highest accuracy

# %%
df = pd.read_csv(
    'LoanStats3b_securev1.csv',          #Load up 2012-2013 loans
    skipinitialspace=True,
    header=1
)

loans2 = df[can_use + ['loan_status']]
loans2 = loans2[:-2]             #remove null rows
# Out:
# /home/alliedtoasters/anaconda3/envs/dspy3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (0,49,129,130,131,134,135,136,139) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
loans2 = treat_loan_data(loans2, 2013)
# Out:
# /home/alliedtoasters/thinkful/loans/cleaning_funcs.py:214: RuntimeWarning: divide by zero encountered in log
#   loans['log_used_cred'] = np.where(loans.used_cred_bal < 1, 0, np.log(loans.used_cred_bal)) #log of used cred bal

# %%
loans2['is_good'] = np.where((loans2.loan_status.isin(good_statuses)), 1, 0)
Y_13 = loans2.is_good
X_13 = loans2[fts]

# %%
Y_13_ = max_perf.predict(X_13)
pd.crosstab(Y_13_, Y_13)   
#As one might expect, the maximum-performing model is way too conservative, only recommending 5 loans.
#They are all perform perfectly, though!
# Out:
# is_good      0       1
# row_0
# 0        29597  158579
# 1            0       5

# %%
Y_13_ = perf_97.predict(X_13)
tb = pd.crosstab(Y_13_, Y_13)
print(tb)
print('failure rate: ', tb.iloc[1,0]/(tb.iloc[1,1]+tb.iloc[1,0])) 
#The 97% threshold model recommends only ~2,000 loans
#but comes close to the expected failure rate of 3%
# Out:
# is_good      0       1
# row_0
# 0        29534  156622
# 1           63    1962
# failure rate:  0.0321100917431

# %%
Y_13_ = mdm_mod.predict(X_13)
tb = pd.crosstab(Y_13_, Y_13)
print(tb)
print('failure rate: ', tb.iloc[1,0]/(tb.iloc[1,1]+tb.iloc[1,0]))         
#The moderate model makes a lot of recommendations, but with a failure rate close to 13%
# Out:
# is_good      0       1
# row_0
# 0        14877   44147
# 1        14720  114437
# failure rate:  0.1286297264

# %%
Y_13_ = max_acc.predict(X_13)
tb = pd.crosstab(Y_13_, Y_13)
print(tb)     #Maximum accuracy model recommends all loans.
print('failure rate: ', int(tb[0])/(int(tb[0])+int(tb[1])))
# Out:
# is_good      0       1
# row_0
# 1        29597  158584
# failure rate:  0.15727942778495171

# %% [markdown]
# <H2>Conclusion</H2>
#
# While the lasso regression offered some of the best results on the holdout set, these extreme models did poorly on the future data set.
# Ultimately, the best performer in a "real" setting was the more moderate ridge regression model. This seems to be a "goldilocks" model. When used on a different data set (loans from 2012-13), it offers a failure rate of 12.9% on its recommended loans, which is a significant improvement over the overall loan default/charge-off rate of 15.3%.
